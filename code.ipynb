# %%
import pandas as pd

df = pd.read_csv("data.csv")
df
# Out:
#     name           rolle    stadt  jahre_erfahrung
# 0    Mia    Data Analyst   Berlin                3
# 1  Jonas  Data Scientist  Hamburg                5
